# %% [markdown]
# # Курс "Python для анализа данных"
#
# ---
# # Домашнее задание LIGHT
# #5.1.2 Примеры использования библиотеки Matplotlib

# %%
# Запустите код ниже для старта, но не правьте во избежания ошибок проверки!
_HOMEWORK_NAME_ = '5.1.2_LIGHT'
_HOMEWORK_ANSWER_DICT_ = dict()

# %% [markdown]
# ## ФИО участника

# %%
# Введите ваше имя и фамилию в соответствующую позицию 'NAME' и 'LAST_NAME'!
_NAME_SERNAME_ = {
    'NAME' : 'Vladimir',
    'LAST_NAME' : 'Doronin'
}

# %% [markdown]
# ## Задание 1

# %% [markdown]
# **Условие:**
# Выведите на экран картинку ```ascent```, которая подгружается кодом ниже. Сколько людей на ней изображено?
#
# **Формат ответа:**
# Число (например, ```5```)
#
# **Оценка в баллах:** 2 балла

# %% [markdown]
# **Решение:**

# %%
from scipy import misc
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

img = misc.ascent()
plt.imshow(img)
plt.show()

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A1'] = 2

# %% [markdown]
# ## Задание 2

# %% [markdown]
# **Условие:**
# Создайте случайную выборку из ```1000000``` значений, полученную в результате реализации случайной величины, распределенной по равномерному закону на множестве целых чисел из отрезка ```[1,100]```. Постройте гистограмму для полученного массива с параметром ```bins=100```. Укажите среднее значение в полученном массиве.
#
# **Формат ответа:**
# Число (например, ```3.4```)
#
# **Оценка в баллах:** 3 балла

# %% [markdown]
# **Решение:**

# %%
x = np.random.randint(1,101, 1000000)
plt.hist(x, 100)
plt.show()
ans2 = x.mean()
assert(ans2 > 48 and ans2 < 52)

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A2'] = ans2

# %% [markdown]
# ## Задание 3

# %% [markdown]
# **Условие:**
# Создайте возрастающую последовательность четных чисел от ```2``` до ```200``` и сделайте из нее массив размера ```10x10```. Постройте тепловую карту полученного массива. Укажите среднее значение в полученном массиве.Сколько на ваш взгляд различных оттенков цвета потребовалось для отрисовки карты?
#
# **Формат ответа:**
# Число (например, ```50```)
#
# **Оценка в баллах:** 3 балла

# %% [markdown]
# **Решение:**

# %%
x = np.arange(2,201,2).reshape(10,10)
plt.imshow(x)
plt.colorbar()
plt.show()
print(x.mean())
# Out:
# 101.0

# %% [markdown]
# **Ответ:**

# %%
# Не изменяйте текст до знака = во избежании ошибок проверки!
_HOMEWORK_ANSWER_DICT_['A3'] = 100
# because 100 different value

# %% [markdown]
# ## Комментарии участника

# %%
_YOUR_COMMENT_ = 'All right!'

# %% [markdown]
# ## Создание отчета

# %%
# Проверьте правильность заполнения полей и 
# выполните данный код для создания отчета
# и сохранения на локальную машину
from google.colab import files
import json
try:
  # form a report
  _HM_REPORT_ = {'Answers':_HOMEWORK_ANSWER_DICT_,
                'Comment':_YOUR_COMMENT_,
                'User':_NAME_SERNAME_,
                }

  # create a report name
  _REPORT_NAME_ = 'HM_' +\
                    _HOMEWORK_NAME_ + \
                  '_by_' + \
                  _NAME_SERNAME_['LAST_NAME'] + \
                  '.json'
  
  # Save a report to a file
  f = open(_REPORT_NAME_,"w")
  f.write(json.dumps(_HM_REPORT_))
  f.close()

  # Donwnload the file into a local host
  files.download(_REPORT_NAME_) 
  print('Thanks for the work, {name}!'.format(name=_NAME_SERNAME_['NAME']))
except Exception as error:
   print(error)
   print('Something went wrong! Check the data entry and try again!')
# Out:
# Thanks for the work, Vladimir!
